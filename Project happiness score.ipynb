# %%
#Name=Vipul Anand
#Project-World Happines Report Project
#Batch=DS2312

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.shape
# Out:
# (158, 12)

# %%
data.isna().sum()
#So we can see that the data has no null values present
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Since in this dataset we have country and happiness rank column and these columns are unique for all the rows so we must delete them
data.drop(columns=['Country','Happiness Rank'],inplace=True)
data
# Out:
#                               Region  Happiness Score  Standard Error  \
# 0                     Western Europe            7.587         0.03411
# 1                     Western Europe            7.561         0.04884
# 2                     Western Europe            7.527         0.03328
# 3                     Western Europe            7.522         0.03880
# 4                      North America            7.427         0.03553
# ..                               ...              ...             ...
# 153               Sub-Saharan Africa            3.465         0.03464
# 154               Sub-Saharan Africa            3.340         0.03656
# 155  Middle East and Northern Africa            3.006         0.05015
# 156               Sub-Saharan Africa            2.905         0.08658
# 157               Sub-Saharan Africa            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#let us check the datatype of each of the columns
data.dtypes
# Out:
# Region                            object
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#here only the region column is a object datatype other all colunms are float
#So let us first change the values in the region columns in data to numerical values
data['Region'].value_counts()
# Out:
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc= LabelEncoder()
df=lab_enc.fit_transform(data['Region'])

# %%
data['Region']=df

# %%
data
# Out:
#      Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0         9            7.587         0.03411                   1.39651
# 1         9            7.561         0.04884                   1.30232
# 2         9            7.527         0.03328                   1.32548
# 3         9            7.522         0.03880                   1.45900
# 4         5            7.427         0.03553                   1.32629
# ..      ...              ...             ...                       ...
# 153       8            3.465         0.03464                   0.22208
# 154       8            3.340         0.03656                   0.28665
# 155       4            3.006         0.05015                   0.66320
# 156       8            2.905         0.08658                   0.01530
# 157       8            2.839         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
data.dtypes
# Out:
# Region                             int32
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#the value counts of each of the column
print(data.value_counts())
# Out:
# Region  Happiness Score  Standard Error  Economy (GDP per Capita)  Family   Health (Life Expectancy)  Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual
# 0       7.284            0.04083         1.33358                   1.30923  0.93156                   0.65124  0.35637                        0.43562     2.26646              1
# 8       3.845            0.03602         0.06940                   0.77265  0.29707                   0.47692  0.15639                        0.19387     1.87877              1
#         3.587            0.04324         0.25812                   0.85188  0.27125                   0.39493  0.12832                        0.21747     1.46494              1
#         3.655            0.05141         0.46534                   0.77115  0.15185                   0.46866  0.17922                        0.20165     1.41723              1
# ...

# %%
for i in data.columns:
    print(data[i].value_counts())
# Out:
# Region
# 8    40
# 1    29
# 3    22
# 9    21
# 4    20
# 6     9
# 7     7
# 2     6
# 5     2
# 0     2
# Name: count, dtype: int64
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: count, Length: 157, dtype: int64
# Standard Error
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# 0.04251    1
# 0.03843    1
# 0.05371    1
# 0.06727    1
# Name: count, Length: 153, dtype: int64
# Economy (GDP per Capita)
# 1.39651    1
# 0.39753    1
# 1.15406    1
# 1.02564    1
# 1.12094    1
#           ..
# 1.12254    1
# 1.18498    1
# 1.14723    1
# 0.59325    1
# 0.20868    1
# Name: count, Length: 158, dtype: int64
# Family
# 1.34951    1
# 0.43106    1
# 0.92933    1
# 0.80001    1
# 1.20215    1
#           ..
# 1.12241    1
# 1.27385    1
# 1.25745    1
# 1.14184    1
# 0.13995    1
# ...

# %%
#plotting the heatmap to show if there are any nulls in the data
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
#So in this data there is no null values

# %%
data.nunique()
# Out:
# Region                            10
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
data.nunique()
# Out:
# Region                            10
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#Let us do the statistical analysis of the data
data.describe()
# Out:
#            Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# count  158.000000       158.000000      158.000000                158.000000
# mean     5.120253         5.375734        0.047885                  0.846137
# std      2.993321         1.145010        0.017146                  0.403121
# min      0.000000         2.839000        0.018480                  0.000000
# 25%      3.000000         4.526000        0.037268                  0.545808
# 50%      4.500000         5.232500        0.043940                  0.910245
# 75%      8.000000         6.243750        0.052300                  1.158448
# max      9.000000         7.587000        0.136930                  1.690420
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  158.000000                158.000000  158.000000
# mean     0.991046                  0.630259    0.428615
# std      0.272369                  0.247078    0.150693
# ...

# %%
#from this the data looks clean but still let us plot the distribution plot to see

# %%
plt.figure(figsize=(15,6))
plotnumber=1
for i in data:
    plt.subplot(2,5,plotnumber)
    sns.distplot(data[i])
    plotnumber+=1
plt.show()

# %%
#from this the data looks clean but still we have to plot boxplot to detect the outliers

# %%
plt.figure(figsize=(15,6))
plotnumber=1
for i in data:
    plt.subplot(2,5,plotnumber)
    sns.boxplot(data[i])
    plt.ylabel(i)
    plt.xlabel(i)
    plotnumber+=1
plt.show()

# %%
#so we can see that there are some outliers in the standard error , family ,trust,generousity and rhe dystopis residual

# %%
#So now let us remove the outliers from the data

# %%
x=data.drop(columns='Happiness Score')
y=data['Happiness Score']

# %%
from scipy.stats import zscore
a=np.abs(zscore(x))

# %%
#The index where the zscore value is greater than 3
index=a[(a<3).all(axis=1)].index
#using this we are able to retain the 97% of the data and remove the outliers also

# %%
#making a new dataframe 
data1=data.iloc[index]

# %%
#checking the no. of rows lost
print(((data.shape[0] - data1.shape[0]) / data.shape[0]) * 100)
# Out:
# 5.69620253164557

# %%
#so we only lost 5% of the data which is okay

# %%
#now let us check the distribution again
plt.figure(figsize=(15,6))
plotnumber=1
for column in data1:
    if plotnumber<=10:
        plt.subplot(2,5,plotnumber)
        sns.distplot(data1[column])
        plt.xlabel(column)
        plt.ylabel(column)
    plotnumber+=1
plt.show()

# %%
#so the data is bit clean now

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, 0 to 156
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         149 non-null    int32
#  1   Happiness Score                149 non-null    float64
#  2   Standard Error                 149 non-null    float64
#  3   Economy (GDP per Capita)       149 non-null    float64
#  4   Family                         149 non-null    float64
#  5   Health (Life Expectancy)       149 non-null    float64
#  6   Freedom                        149 non-null    float64
#  7   Trust (Government Corruption)  149 non-null    float64
#  8   Generosity                     149 non-null    float64
#  9   Dystopia Residual              149 non-null    float64
# dtypes: float64(9), int32(1)
# memory usage: 12.2 KB

# %%
data1.describe()
# Out:
#            Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# count  149.000000       149.000000      149.000000                149.000000
# mean     5.080537         5.429611        0.046241                  0.862163
# std      3.032519         1.111256        0.014043                  0.387975
# min      0.000000         2.905000        0.018480                  0.000000
# 25%      3.000000         4.610000        0.036800                  0.593250
# 50%      4.000000         5.268000        0.043610                  0.920490
# 75%      8.000000         6.295000        0.050690                  1.159910
# max      9.000000         7.587000        0.098110                  1.563910
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  149.000000                149.000000  149.000000
# mean     1.008623                  0.638624    0.427449
# std      0.251890                  0.245937    0.150864
# ...

# %%
#now let us see the correlation matrix of the data
corr=data.corr()

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr,annot=True,linewidths=0.1)
# Out:
# <Axes: >

# %%
corr['Happiness Score'].sort_values(ascending=False)
#all the values are very much related to the label
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Region                          -0.176791
# Standard Error                  -0.177254
# Name: Happiness Score, dtype: float64

# %%
#dividing the dataset into feature and label
x=data1.drop(columns='Happiness Score')
y=data1['Happiness Score']

# %%
#apply standardscaler on the data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled=pd.DataFrame(x_scaled,columns=x.columns)

# %%
#Now let us check the variance inflation factor of each the column

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled.values,i) for i in range(9)]
vif['columns']=x.columns

# %%
vif
# Out:
#         vif                        columns
# 0  1.420880                         Region
# 1  1.187656                 Standard Error
# 2  4.277028       Economy (GDP per Capita)
# 3  1.942085                         Family
# 4  3.982022       Health (Life Expectancy)
# 5  1.868880                        Freedom
# 6  1.497593  Trust (Government Corruption)
# 7  1.473424                     Generosity
# 8  1.036508              Dystopia Residual

# %%
#Here we can see that all the values are in a relevant range so we do not need to delete any of them

# %%
#in the coorelation matric we came to see that the economy and he health were having very high score
#so let us analyse more about them so that we can come to the conclusion to delete one of them or not

# %%
data1
plt.scatter(x='Economy (GDP per Capita)',y='Health (Life Expectancy)',data=data1)
plt.xlabel('Economy')
plt.ylabel('Health')
# Out:
# Text(0, 0.5, 'Health')

# %%
#so they are related so we can drop one of them and as enonomy is more related the the label so will drop health
x=data1.drop(columns=['Health (Life Expectancy)','Happiness Score'])
y=data1['Happiness Score']

# %%
x_scaled=pd.DataFrame(x_scaled,columns=x.columns)

# %%
x_scaled
# Out:
#        Region  Standard Error  Economy (GDP per Capita)    Family   Freedom  \
# 0    1.296837       -0.866786                  1.381916  1.357879  1.583704
# 1    1.296837        0.185669                  1.138324  1.567882  1.338953
# 2    1.296837       -0.926089                  1.198220  1.401974  1.476027
# 3    1.296837       -0.531687                  1.543526  1.283947  1.611371
# 4   -0.026647       -0.765327                  1.200315  1.250726  1.366887
# ..        ...             ...                       ...       ...       ...
# 144  0.965966        0.369294                 -1.026255 -0.945943  0.274090
# 145  0.965966       -0.214450                 -1.562163 -0.624365 -0.216276
# 146  0.635095       -1.100427                 -1.402596 -2.811354 -1.285662
# 147  0.965966       -0.691734                 -1.488379 -2.608163  0.379439
# 148  0.965966        2.882182                 -2.190139 -2.361154 -2.054764
#
# ...

# %%
#now let us train out model in first case with x,y
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import LassoCV #ridge and the lassocv also act as a feature selector
from sklearn.model_selection import cross_val_score

# %%
# we will use the linear randomforestRegressor to check the best random state
maxACC=0
maxrs=0
for i in range(1,200):
    rf=RandomForestRegressor()
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=i)
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxACC:
        maxACC=acc
        maxrs=i
print(maxACC,maxrs)
# Out:
# 0.9531241749508582 120

# %%
#since the best accuracy is 0.811 and best random state is 86 so let us just proceed
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=120)

# %%
rr=RandomForestRegressor()
er=ExtraTreesRegressor()
lr=LinearRegression()
gb=GradientBoostingRegressor()
ad=AdaBoostRegressor()
bg=BaggingRegressor()
ri=Ridge()
ls=LassoCV()

# %%
models=[rr,er,lr,gb,ad,bg,ri,ls]

# %%
accuracy={}
for model in models:
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    accuracy[model]=r2_score(y_test,pred)
print(accuracy)
# Out:
# {RandomForestRegressor(): 0.9444156095947001, ExtraTreesRegressor(): 0.9627970353641626, LinearRegression(): 0.9858184027499637, GradientBoostingRegressor(): 0.9538223774849139, AdaBoostRegressor(): 0.8996702173629246, BaggingRegressor(): 0.9365584951295224, Ridge(): 0.9854921505895083, LassoCV(): 0.9857626568712199}

# %%
accuracy
# Out:
# {RandomForestRegressor(): 0.9444156095947001,
#  ExtraTreesRegressor(): 0.9627970353641626,
#  LinearRegression(): 0.9858184027499637,
#  GradientBoostingRegressor(): 0.9538223774849139,
#  AdaBoostRegressor(): 0.8996702173629246,
#  BaggingRegressor(): 0.9365584951295224,
#  Ridge(): 0.9854921505895083,
#  LassoCV(): 0.9857626568712199}

# %%
#Now let us verify the things with the cross validation
from sklearn.model_selection import cross_val_score

# %%
for model in models:
    print(model,',',cross_val_score(model,x_scaled,y,cv=5).mean())
# Out:
# RandomForestRegressor() , -4.267044908551153
# ExtraTreesRegressor() , -3.5049006770806583
# LinearRegression() , 0.605190291611015
# GradientBoostingRegressor() , -2.493906988230294
# AdaBoostRegressor() , -6.065418250365168
# BaggingRegressor() , -4.595049991578452
# Ridge() , 0.592226074463042
# LassoCV() , 0.6029791424948823

# %%
#so we can clearly see the dominance of the linear regression

# %%
model=LinearRegression()

# %%
#so we will do the hyperparameter tuning of the linerar regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'fit_intercept': [True, False],
    'copy_X': [True, False],
    'n_jobs': [None, 1, 2, 4, -1],
    'positive': [True, False]
}

# %%
grid_search = GridSearchCV(model, param_grid, cv=5)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [None, 1, 2, 4, -1],
#                          'positive': [True, False]})

# %%
print(grid_search.best_score_,grid_search.best_estimator_)
# Out:
# 0.9847840971229159 LinearRegression()

# %%
grid_search.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#so let us just apply these params to the model
lr=LinearRegression(copy_X=True,fit_intercept=True,n_jobs=None,positive=False)

# %%
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.9858184027499637

# %%
y_pred_train=lr.predict(x_train)
print('The r2_score for the train is',r2_score(y_train,y_pred_train))
print('The r2_score for the test is',r2_score(y_test,pred))
# Out:
# The r2_score for the train is 0.9882346093625455
# The r2_score for the test is 0.9858184027499637

# %%
#The final conclusions and the results
#So The accuracy of our final and the best model is Linear regression
print('the final model with the best accuacy is',LinearRegression())
print('the r2_score of the model is',r2_score(y_test,pred))
print('the mean absolute error of the model is', mean_absolute_error(y_test,pred))
print('the mean squared error of the model is', mean_squared_error(y_test,pred))
print('the root mean squared error of the model is', np.sqrt(mean_absolute_error(y_test,pred)))
# Out:
# the final model with the best accuacy is LinearRegression()
# the r2_score of the model is 0.9858184027499637
# the mean absolute error of the model is 0.08710643567002843
# the mean squared error of the model is 0.017123441748080052
# the root mean squared error of the model is 0.29513799428407794
